# %%
#import Data Manipulation Library
import numpy as np
import pandas as pd
#import data visualization library
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/Titanic.csv')

# %%
df.describe()
# Out:
#        PassengerId       Pclass          Age        SibSp        Parch  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean    500.500000     1.964000    38.458000     2.032000     2.005000
# std     288.819436     0.820596    23.103723     1.424431     1.410306
# min       1.000000     1.000000     1.000000     0.000000     0.000000
# 25%     250.750000     1.000000    19.000000     1.000000     1.000000
# 50%     500.500000     2.000000    36.500000     2.000000     2.000000
# 75%     750.250000     3.000000    59.000000     3.000000     3.000000
# max    1000.000000     3.000000    79.000000     4.000000     4.000000
#
#               Fare     Survived
# count  1000.000000  1000.000000
# mean    247.968650     0.492000
# std     139.301211     0.500186
# min      10.020000     0.000000
# 25%     126.295000     0.000000
# 50%     246.500000     0.000000
# 75%     365.662500     1.000000
# max     499.780000     1.000000

# %%
# df.head() #first 5 rows
# df.tail() #last 5 rows
df.sample(frac=1)  #Shuffle dataset, always use this
# Out:
#      PassengerId  Pclass              Name     Sex  Age  SibSp  Parch  \
# 342          343       3    Anthony Harmon  female   47      1      3
# 99           100       1     Stephen Mckee    male   53      3      2
# 607          608       2       David Lopez    male   76      4      0
# 944          945       3  Francis Robinson    male   45      0      0
# 353          354       1   Michael Farrell    male   76      0      0
# ..           ...     ...               ...     ...  ...    ...    ...
# 266          267       3   Kimberly Gibson    male   65      1      1
# 584          585       1       Jamie Baird  female   62      4      0
# 292          293       3       Jeremy Reed    male   37      2      1
# 346          347       1       Sharon Boyd  female   43      3      1
# 179          180       1   Robert Oconnell    male   22      3      2
#
#                                    Ticket    Fare Embarked  Survived
# ...

# %%
#checking info for dataset
df.info() #object-categorical, float/int- numerical
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1000 non-null   int64
#  1   Pclass       1000 non-null   int64
#  2   Name         1000 non-null   object
#  3   Sex          1000 non-null   object
#  4   Age          1000 non-null   int64
#  5   SibSp        1000 non-null   int64
#  6   Parch        1000 non-null   int64
#  7   Ticket       1000 non-null   object
#  8   Fare         1000 non-null   float64
#  9   Embarked     1000 non-null   object
#  10  Survived     1000 non-null   int64
# dtypes: float64(1), int64(6), object(4)
# memory usage: 86.1+ KB

# %%
df['Pclass'].value_counts()
# Out:
# Pclass
# 1    355
# 2    326
# 3    319
# Name: count, dtype: int64

# %%
df['Embarked'].value_counts()
# Out:
# Embarked
# Q    362
# C    328
# S    310
# Name: count, dtype: int64

# %%
df['Sex'].value_counts()
# Out:
# Sex
# male      527
# female    473
# Name: count, dtype: int64

# %%
df['Survived'].value_counts()
# Out:
# Survived
# 0    508
# 1    492
# Name: count, dtype: int64

# %%
# S : Southampton
S = df[df['Embarked']=='S']

# %%
# Q : Qweenstown
Q = df[df['Embarked']=='Q']

# %%
# C : Chelsburg
C = df[df['Embarked']=='C']

# %%
S['Pclass'].value_counts()
# Out:
# Pclass
# 1    113
# 2    100
# 3     97
# Name: count, dtype: int64

# %%
S['Pclass'].value_counts().plot(kind='pie', autopct='%0.2f%%')

plt.title('People boarding from Southampton')
plt.show()

# %%
S['Survived'].value_counts().plot(kind='pie',autopct='%.2f',explode=[0.07,0]) #survived in southampton
plt.title('Survived in Southampton')
plt.show()

# %%
S['Sex'].value_counts().plot(kind='pie',autopct='%.2f',explode=[0.07,0]) #survived in southampton
plt.title('SUrvived in Southampton')
plt.show()

# %%
Q['Survived'].value_counts().plot(kind='pie',autopct='%.2f',explode=[0.07,0])
plt.title('Survived in Qweenstown')
plt.show()

# %%
C['Survived'].value_counts().plot(kind='pie',autopct='%.2f',explode=[0.07,0]) #survived in southampton
plt.title('Survived in Chelsburg')
plt.show()

# %%
# Sagregate numerical and categorical columns
#object matlab categorical, exclude categorical to get numericals
numerical_columns = df.select_dtypes(exclude='object')
numerical_columns
# Out:
#      PassengerId  Pclass  Age  SibSp  Parch    Fare  Survived
# 0              1       3   17      4      2  144.08         1
# 1              2       1   60      2      2  249.04         0
# 2              3       3   64      0      0   50.31         1
# 3              4       3   35      4      0  235.20         1
# 4              5       1   70      0      3  160.17         1
# ..           ...     ...  ...    ...    ...     ...       ...
# 995          996       2   69      2      3   19.87         1
# 996          997       2   61      4      4   85.35         0
# 997          998       3   10      4      1  444.22         0
# 998          999       3   50      3      2  234.67         1
# 999         1000       1    3      3      3  286.65         1
#
# [1000 rows x 7 columns]

# %%
# Sagregate numerical and categorical columns
#NOTE: to handle large dataset first sagregate num/catergorical data
#object matlab categorical, keep categorical
numerical_columns = df.select_dtypes(include='object')
numerical_columns
# Out:
#                   Name     Sex                                Ticket Embarked
# 0         Allison Hill    male  43d75413-a939-4bd1-a516-b0d47d3572cc        Q
# 1          Noah Rhodes    male  6334fa2a-8b4b-47e7-a451-5ae01754bf08        S
# 2      Angie Henderson    male  61a66444-e2af-4629-9efb-336e2f546033        Q
# 3        Daniel Wagner    male  0b6c03c8-721e-4419-afc3-e6495e911b91        C
# 4      Cristian Santos  female  436e3c49-770e-49db-b092-d40143675d58        C
# ..                 ...     ...                                   ...      ...
# 995      Brittany Ward    male  75eb0e8f-a090-460d-a7c7-655a7b434a72        Q
# 996     Edward Stanley  female  e55b93ad-8976-4471-9d7f-57d1e45def26        C
# 997  Christina Johnson    male  d06d3943-c8b3-415e-b664-704355c9bf0f        C
# 998       Edgar Miller    male  0e5779ec-be1a-470f-ad83-a4c869f8d3e4        S
# 999  Elizabeth Sanders    male  90a014ab-4ca1-4abd-8565-0e0bd5c97d5d        C
#
# [1000 rows x 4 columns]

# %%
#Removing two columns form df, by passing list and inplace= true:

df.drop(columns=['Ticket','Name'],axis = 1,inplace=True) #error already deleted

# %%
df
# Out:
#      PassengerId  Pclass     Sex  Age  SibSp  Parch    Fare Embarked  Survived
# 0              1       3    male   17      4      2  144.08        Q         1
# 1              2       1    male   60      2      2  249.04        S         0
# 2              3       3    male   64      0      0   50.31        Q         1
# 3              4       3    male   35      4      0  235.20        C         1
# 4              5       1  female   70      0      3  160.17        C         1
# ..           ...     ...     ...  ...    ...    ...     ...      ...       ...
# 995          996       2    male   69      2      3   19.87        Q         1
# 996          997       2  female   61      4      4   85.35        C         0
# 997          998       3    male   10      4      1  444.22        C         0
# 998          999       3    male   50      3      2  234.67        S         1
# 999         1000       1    male    3      3      3  286.65        C         1
#
# [1000 rows x 9 columns]

# %%
#convert categoricals into different columns(raste me aane wale categories column bana dega)
'''Types of Encodings
1. get_dummies/OneHotEncoding same and makes more columns,2. Ordinal encoding: if in a order apply this if columns in order,
3. Label encoding: count the labels jo pehele aaya count
'''
data = pd.get_dummies(df,dtype ='int') #dont use these
data
# Out:
#      PassengerId  Pclass  Age  SibSp  Parch    Fare  Survived  Sex_female  \
# 0              1       3   17      4      2  144.08         1           0
# 1              2       1   60      2      2  249.04         0           0
# 2              3       3   64      0      0   50.31         1           0
# 3              4       3   35      4      0  235.20         1           0
# 4              5       1   70      0      3  160.17         1           1
# ..           ...     ...  ...    ...    ...     ...       ...         ...
# 995          996       2   69      2      3   19.87         1           0
# 996          997       2   61      4      4   85.35         0           1
# 997          998       3   10      4      1  444.22         0           0
# 998          999       3   50      3      2  234.67         1           0
# 999         1000       1    3      3      3  286.65         1           0
#
#      Sex_male  Embarked_C  Embarked_Q  Embarked_S
# ...

# %%
#Label encoding

from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()                                     #initiate a variable and put function
df['Sex'] = le.fit_transform(df['Sex'])
# data['Embarked'] = le.fit_transform(data['Embarked'])
# data

# %%
df
# Out:
#      PassengerId  Pclass  Sex  Age  SibSp  Parch    Fare Embarked  Survived
# 0              1       3    1   17      4      2  144.08        Q         1
# 1              2       1    1   60      2      2  249.04        S         0
# 2              3       3    1   64      0      0   50.31        Q         1
# 3              4       3    1   35      4      0  235.20        C         1
# 4              5       1    0   70      0      3  160.17        C         1
# ..           ...     ...  ...  ...    ...    ...     ...      ...       ...
# 995          996       2    1   69      2      3   19.87        Q         1
# 996          997       2    0   61      4      4   85.35        C         0
# 997          998       3    1   10      4      1  444.22        C         0
# 998          999       3    1   50      3      2  234.67        S         1
# 999         1000       1    1    3      3      3  286.65        C         1
#
# [1000 rows x 9 columns]

# %%
df['Embarked'] = le.fit_transform(df['Embarked']) #encodes C-0,Q-1,S-2 in order
df
# Out:
#      PassengerId  Pclass  Sex  Age  SibSp  Parch    Fare  Embarked  Survived
# 0              1       3    1   17      4      2  144.08         1         1
# 1              2       1    1   60      2      2  249.04         2         0
# 2              3       3    1   64      0      0   50.31         1         1
# 3              4       3    1   35      4      0  235.20         0         1
# 4              5       1    0   70      0      3  160.17         0         1
# ..           ...     ...  ...  ...    ...    ...     ...       ...       ...
# 995          996       2    1   69      2      3   19.87         1         1
# 996          997       2    0   61      4      4   85.35         0         0
# 997          998       3    1   10      4      1  444.22         0         0
# 998          999       3    1   50      3      2  234.67         2         1
# 999         1000       1    1    3      3      3  286.65         0         1
#
# [1000 rows x 9 columns]
