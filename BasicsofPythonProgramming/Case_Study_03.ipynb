# %%
#import data manipulation libraries
import pandas as pd
import numpy as np

#import data visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns

#import filter warning libraries
import warnings
warnings.filterwarnings('ignore')     #to filter warnings, ignore warnings

# %%
df = pd.read_csv('/content/Model.csv')
df.sample(frac = 1)   #SHuffle dataset
# Out:
#              Make         Model  Year                Engine Fuel Type  \
# 9828          Kia       Sorento  2016                regular unleaded
# 2236       Toyota  Camry Solara  2008                regular unleaded
# 1034         Audi            A3  2016  premium unleaded (recommended)
# 5665   Volkswagen           GTI  2013  premium unleaded (recommended)
# 6170          GMC         Jimmy  2000                regular unleaded
# ...           ...           ...   ...                             ...
# 1976    Chevrolet        Blazer  2004                regular unleaded
# 11124       Volvo           V60  2015                regular unleaded
# 7707       Toyota         Prius  2017                regular unleaded
# 2489        Dodge       Charger  2016  premium unleaded (recommended)
# 869          Saab           9-5  2011  premium unleaded (recommended)
#
#        Engine HP  Engine Cylinders Transmission Type      Driven_Wheels  \
# ...

# %%
#Checking descriptive stats
df.describe()
#Data is non-normally disributed, Mean !=Median
# Out:
#                Year    Engine HP  Engine Cylinders  Number of Doors  \
# count  11914.000000  11845.00000      11884.000000     11908.000000
# mean    2010.384338    249.38607          5.628829         3.436093
# std        7.579740    109.19187          1.780559         0.881315
# min     1990.000000     55.00000          0.000000         2.000000
# 25%     2007.000000    170.00000          4.000000         2.000000
# 50%     2015.000000    227.00000          6.000000         4.000000
# 75%     2016.000000    300.00000          6.000000         4.000000
# max     2017.000000   1001.00000         16.000000         4.000000
#
#         highway MPG      city mpg    Popularity          MSRP
# count  11914.000000  11914.000000  11914.000000  1.191400e+04
# mean      26.637485     19.733255   1554.911197  4.059474e+04
# std        8.863001      8.987798   1441.855347  6.010910e+04
# min       12.000000      7.000000      2.000000  2.000000e+03
# ...

# %%
#Checking info about the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               11914 non-null  object
#  1   Model              11914 non-null  object
#  2   Year               11914 non-null  int64
#  3   Engine Fuel Type   11911 non-null  object
#  4   Engine HP          11845 non-null  float64
#  5   Engine Cylinders   11884 non-null  float64
#  6   Transmission Type  11914 non-null  object
#  7   Driven_Wheels      11914 non-null  object
#  8   Number of Doors    11908 non-null  float64
#  9   Market Category    8172 non-null   object
#  10  Vehicle Size       11914 non-null  object
#  11  Vehicle Style      11914 non-null  object
#  12  highway MPG        11914 non-null  int64
#  13  city mpg           11914 non-null  int64
#  14  Popularity         11914 non-null  int64
#  15  MSRP               11914 non-null  int64
# ...

# %%
#Missing vALUES INFO wrt graph
df.isnull().sum().plot(kind = 'barh', colormap = 'viridis')
plt.show()

# %%
#Checking Descriptive Stats: Univariate Analysis
'''
As Mean != Median the data is skewed/Non Normally Distributed.
'''
df.describe()
# Out:
#                Year    Engine HP  Engine Cylinders  Number of Doors  \
# count  11914.000000  11845.00000      11884.000000     11908.000000
# mean    2010.384338    249.38607          5.628829         3.436093
# std        7.579740    109.19187          1.780559         0.881315
# min     1990.000000     55.00000          0.000000         2.000000
# 25%     2007.000000    170.00000          4.000000         2.000000
# 50%     2015.000000    227.00000          6.000000         4.000000
# 75%     2016.000000    300.00000          6.000000         4.000000
# max     2017.000000   1001.00000         16.000000         4.000000
#
#         highway MPG      city mpg    Popularity          MSRP
# count  11914.000000  11914.000000  11914.000000  1.191400e+04
# mean      26.637485     19.733255   1554.911197  4.059474e+04
# std        8.863001      8.987798   1441.855347  6.010910e+04
# min       12.000000      7.000000      2.000000  2.000000e+03
# ...

# %%
#Checking dataset
df.head()
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# ...

# %%
#Calculate make = BMW
df[df['Make'] == 'BMW']
# Out:
#       Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0      BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1      BMW    1 Series  2011  premium unleaded (required)      300.0
# 2      BMW    1 Series  2011  premium unleaded (required)      300.0
# 3      BMW    1 Series  2011  premium unleaded (required)      230.0
# 4      BMW    1 Series  2011  premium unleaded (required)      230.0
# ...    ...         ...   ...                          ...        ...
# 11901  BMW          Z4  2016  premium unleaded (required)      240.0
# 11902  BMW          Z4  2016  premium unleaded (required)      335.0
# 11903  BMW          Z8  2001  premium unleaded (required)      394.0
# 11904  BMW          Z8  2002  premium unleaded (required)      394.0
# 11905  BMW          Z8  2003  premium unleaded (required)      394.0
#
#        Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# ...

# %%
#Calculate make = BMW, Year COUNT
df[df['Make'] == 'BMW']['Year'].value_counts()
# Out:
# Year
# 2015    103
# 2016     93
# 2017     79
# 2014     10
# 2013      9
# 2011      6
# 2001      6
# 2002      5
# 2012      4
# 1995      3
# 2000      3
# 1996      2
# 1997      2
# 2003      2
# 2007      2
# 2006      2
# 2008      2
# 2010      1
# Name: count, dtype: int64

# %%
#Calculate make = BMW, Year plot
df[df['Make'] == 'BMW']['Year'].value_counts().plot(kind = 'bar', colormap = 'viridis')
plt.show()

# %%
#YEAR WISE TOP 5 BMW SALES
#Calculate make = BMW, Year plot
df[df['Make'] == 'BMW']['Year'].value_counts()[:5].plot(kind = 'bar', colormap = 'viridis')
plt.show()

# %%
#Make of CARS UNDER 500000
df[df['MSRP'] < 500000]['Make'].value_counts() #focus on condition first
# Out:
# Make
# Chevrolet        1123
# Ford              881
# Volkswagen        809
# Toyota            746
# Dodge             626
# Nissan            558
# GMC               515
# Honda             449
# Mazda             423
# Cadillac          397
# Mercedes-Benz     353
# Suzuki            351
# BMW               334
# Infiniti          330
# Audi              328
# Hyundai           303
# Volvo             281
# Subaru            256
# Acura             252
# Kia               231
# Mitsubishi        213
# Lexus             202
# Buick             196
# Chrysler          187
# Pontiac           186
# Lincoln           164
# Oldsmobile        150
# Land Rover        143
# Porsche           136
# Saab              111
# Aston Martin       93
# Plymouth           82
# Bentley            74
# Ferrari            68
# FIAT               62
# Scion              60
# Maserati           58
# Lamborghini        48
# Rolls-Royce        31
# Lotus              29
# Tesla              18
# ...

# %%
#Details of car 'Make' having maximum city mileage city mpg
# df['city mpg'].max() i.e, 137
df[df['city mpg'] == 137]
# Out:
#      Make Model  Year Engine Fuel Type  Engine HP  Engine Cylinders  \
# 5790  BMW    i3  2015         electric      170.0               0.0
# 5791  BMW    i3  2016         electric      170.0               0.0
# 5792  BMW    i3  2017         electric      170.0               0.0
#
#      Transmission Type     Driven_Wheels  Number of Doors   Market Category  \
# 5790      DIRECT_DRIVE  rear wheel drive              4.0  Hatchback,Luxury
# 5791      DIRECT_DRIVE  rear wheel drive              4.0  Hatchback,Luxury
# 5792      DIRECT_DRIVE  rear wheel drive              4.0  Hatchback,Luxury
#
#      Vehicle Size  Vehicle Style  highway MPG  city mpg  Popularity   MSRP
# 5790      Compact  4dr Hatchback          111       137        3916  42400
# 5791      Compact  4dr Hatchback          111       137        3916  42400
# 5792      Compact  4dr Hatchback          111       137        3916  42400

# %%
#Details of car 'Make' having maximum city mileage highway MPG
df['highway MPG'].max()
# Out:
# 354

# %%
#Details of car 'Make' having maximum city mileage highway MPG
df[df['highway MPG']==354]
# Out:
#       Make Model  Year                Engine Fuel Type  Engine HP  \
# 1119  Audi    A6  2017  premium unleaded (recommended)      252.0
#
#       Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# 1119               4.0  AUTOMATED_MANUAL  front wheel drive              4.0
#
#      Market Category Vehicle Size Vehicle Style  highway MPG  city mpg  \
# 1119          Luxury      Midsize         Sedan          354        24
#
#       Popularity   MSRP
# 1119        3105  51600

# %%
#Popularity of cars greater than 3000
df[df['Popularity']>3000]
# Out:
#       Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0      BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1      BMW    1 Series  2011  premium unleaded (required)      300.0
# 2      BMW    1 Series  2011  premium unleaded (required)      300.0
# 3      BMW    1 Series  2011  premium unleaded (required)      230.0
# 4      BMW    1 Series  2011  premium unleaded (required)      230.0
# ...    ...         ...   ...                          ...        ...
# 11901  BMW          Z4  2016  premium unleaded (required)      240.0
# 11902  BMW          Z4  2016  premium unleaded (required)      335.0
# 11903  BMW          Z8  2001  premium unleaded (required)      394.0
# 11904  BMW          Z8  2002  premium unleaded (required)      394.0
# 11905  BMW          Z8  2003  premium unleaded (required)      394.0
#
#        Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# ...

# %%
#Visualizing Vehicle Size counts
df['Vehicle Size'].value_counts().plot(kind = 'pie', autopct = '%.2f', explode =[0.01, 0.01,0])
plt.show()

# %%
compact_vehicles = df[df['Vehicle Size'] == 'Compact']

# %%
compact_vehicles
# Out:
#       Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0      BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1      BMW    1 Series  2011  premium unleaded (required)      300.0
# 2      BMW    1 Series  2011  premium unleaded (required)      300.0
# 3      BMW    1 Series  2011  premium unleaded (required)      230.0
# 4      BMW    1 Series  2011  premium unleaded (required)      230.0
# ...    ...         ...   ...                          ...        ...
# 11901  BMW          Z4  2016  premium unleaded (required)      240.0
# 11902  BMW          Z4  2016  premium unleaded (required)      335.0
# 11903  BMW          Z8  2001  premium unleaded (required)      394.0
# 11904  BMW          Z8  2002  premium unleaded (required)      394.0
# 11905  BMW          Z8  2003  premium unleaded (required)      394.0
#
#        Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# ...

# %%
medium_vehicles = df[df['Vehicle Size'] == 'Medium']

# %%
medium_vehicles
# Out:
# Empty DataFrame
# Columns: [Make, Model, Year, Engine Fuel Type, Engine HP, Engine Cylinders, Transmission Type, Driven_Wheels, Number of Doors, Market Category, Vehicle Size, Vehicle Style, highway MPG, city mpg, Popularity, MSRP]
# Index: []

# %%
large_vehicles = df[df['Vehicle Size'] == 'Large']
large_vehicles
# Out:
#                 Make      Model  Year                Engine Fuel Type  \
# 165    Mercedes-Benz  300-Class  1991                regular unleaded
# 171    Mercedes-Benz  300-Class  1991                regular unleaded
# 176    Mercedes-Benz  300-Class  1992                regular unleaded
# 182    Mercedes-Benz  300-Class  1992                          diesel
# 190    Mercedes-Benz  300-Class  1993                          diesel
# ...              ...        ...   ...                             ...
# 11876            GMC      Yukon  2017        flex-fuel (unleaded/E85)
# 11877            GMC      Yukon  2017        flex-fuel (unleaded/E85)
# 11878            GMC      Yukon  2017  premium unleaded (recommended)
# 11879            GMC      Yukon  2017        flex-fuel (unleaded/E85)
# 11880            GMC      Yukon  2017        flex-fuel (unleaded/E85)
#
#        Engine HP  Engine Cylinders Transmission Type     Driven_Wheels  \
# ...

# %%
compact_vehicles['Transmission Type'].value_counts()
# Out:
# Transmission Type
# MANUAL              2173
# AUTOMATIC           2124
# AUTOMATED_MANUAL     416
# DIRECT_DRIVE          45
# UNKNOWN                6
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine Fuel Type        3
# Engine HP              69
# Engine Cylinders       30
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         6
# Market Category      3742
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
df['Engine Fuel Type'].mode()
# Out:
# 0    regular unleaded
# Name: Engine Fuel Type, dtype: object

# %%
df['Engine Fuel Type'].fillna('regular unleaded', inplace = True)

# %%
df.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine Fuel Type        0
# Engine HP              69
# Engine Cylinders       30
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         6
# Market Category      3742
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
df['Engine HP'].quantile(0.75),df['Engine HP'].quantile(0.25)
# Out:
# (np.float64(300.0), np.float64(170.0))

# %%
df['Engine HP'].fillna(200, inplace = True)

# %%
df['Engine Cylinders'].value_counts()
# Out:
# Engine Cylinders
# 4.0     4752
# 6.0     4489
# 8.0     2031
# 12.0     230
# 5.0      225
# 10.0      68
# 0.0       56
# 3.0       30
# 16.0       3
# Name: count, dtype: int64

# %%
df[df['Engine Cylinders'].isnull()]['Engine Fuel Type'].value_counts()
# Out:
# Engine Fuel Type
# premium unleaded (required)    17
# electric                       10
# regular unleaded                3
# Name: count, dtype: int64

# %%
df[df['Engine Cylinders'].isnull()]
# Out:
#             Make    Model  Year             Engine Fuel Type  Engine HP  \
# 1983   Chevrolet  Bolt EV  2017                     electric      200.0
# 1984   Chevrolet  Bolt EV  2017                     electric      200.0
# 3716  Volkswagen   e-Golf  2015                     electric      115.0
# 3717  Volkswagen   e-Golf  2015                     electric      115.0
# 3718  Volkswagen   e-Golf  2016                     electric      115.0
# 3719  Volkswagen   e-Golf  2016                     electric      115.0
# 5778  Mitsubishi   i-MiEV  2014                     electric      200.0
# 5779  Mitsubishi   i-MiEV  2016                     electric       66.0
# 5780  Mitsubishi   i-MiEV  2017                     electric       66.0
# 8373      Toyota  RAV4 EV  2012                     electric      154.0
# 8695       Mazda     RX-7  1993             regular unleaded      255.0
# 8696       Mazda     RX-7  1994             regular unleaded      255.0
# ...

# %%
df['Engine Cylinders'].fillna(4.0, inplace = True) #changes from here

# %%
df
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...
